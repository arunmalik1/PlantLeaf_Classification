# %% [markdown]
# <a href="https://colab.research.google.com/github/arunmalik1/PlantLeaf_Classification/blob/main/PlantLeaf_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This project is binasry classification project using plant images. The idea is to be able to identify diseased vs healthy plants. There are 11 different plants and the entire dataet is divded into 22 categories.
#
# The dataset is from Kaggle.

# %% [markdown]
# #Import Packages

# %%
#import packages 
import pandas as pd
import numpy as np
import scipy

#import plot 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#import keras and tenserflow and pydicom
import keras
import pydicom
from IPython.display import Image
import tensorflow as tf
from keras import layers
from tensorflow.keras.preprocessing import image

# %% [markdown]
# #Import Data

# %%
#install opendatasets to get the data from Kaggle
# !pip install opendatasets --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#need opendatasets to get the data from Kaggle 
import opendatasets as od
od.download("https://www.kaggle.com/datasets/csafrit2/plant-leaves-for-image-classification?select=Plants_2")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: arunmalik78
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 6.56G/6.56G [01:01<00:00, 115MB/s]

# %%
#need pydicom for images
# !pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 53.8 MB/s eta 0:00:00
# ...

# %%
#taking a look at the first image in the train dataset
Image("/content/plant-leaves-for-image-classification/Plants_2/train/Alstonia Scholaris diseased (P2a)/0014_0011.JPG", width=100, height=100)
